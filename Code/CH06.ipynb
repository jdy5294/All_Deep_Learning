# %% [markdown]
# <a href="https://colab.research.google.com/github/jdy5294/All_Deep_Learning/blob/main/Code/CH06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6장. 로지스틱 회귀 모델: 참 거짓 판단하기

# %% [markdown]
# ## 5. 텐서플로에서 실행하는 로지스틱 회귀 모델

# %% [markdown]
# ### 1.환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 2. 데이터 준비

# %%
x = np.array([2, 4, 6, 8, 10, 12, 14])
y = np.array([0, 0, 0, 1, 1, 1, 1])

# %% [markdown]
# ### 3. 모델 실행

# %% [markdown]
# - 교차 엔트로피 오차 함수:
# $-\{y \log h + (1-y) \log (1-h)\}$

# %%
model = Sequential()
model.add(Dense(1, input_dim=1, activation='sigmoid'))

model.compile(optimizer='sgd' ,loss='binary_crossentropy') # 'binary_crossentropy': 교차 엔트로피 오차 함수
model.fit(x, y, epochs=5000)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2657
# Epoch 2502/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2657
# Epoch 2503/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2656
# Epoch 2504/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2656
# Epoch 2505/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2655
# Epoch 2506/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2655
# Epoch 2507/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2654
# Epoch 2508/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2654
# Epoch 2509/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2653
# Epoch 2510/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2653
# Epoch 2511/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2652
# Epoch 2512/5000
# ...

# %% [markdown]
# ### 4. 모델 테스트

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x),'r')
plt.show()
# Out:
# 1/1 [==============================] - 0s 85ms/step

# %%
hour = 7
prediction = model.predict([hour])

print("%.f시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다" % (hour, prediction * 100))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 7시간을 공부할 경우, 합격 예상 확률은 59.8%입니다
